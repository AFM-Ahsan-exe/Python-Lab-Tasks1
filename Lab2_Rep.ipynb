# %% [markdown]
# # ***Lab Task 1: Student Grade Calculator***

# %%
marks = int(input("Enter marks (1-100): "))

if marks < 1 or marks > 100:
    print("Invalid input")
elif marks < 50:
    print("Grade: F")
elif marks <= 60:
    print("Grade: E")
elif marks <= 70:
    print("Grade: D")
elif marks <= 80:
    print("Grade: C")
elif marks <= 90:
    print("Grade: B")
else:
    print("Grade: A")
# Out:
# Enter marks (1-100): 19999
# Invalid input

# %%
n = int(input("Enter number of terms: "))

if n <= 0:
    print("Invalid input")
else:
    a = 0
    b = 1
    for i in range(n):
        print(a, end=" ")
        c = a + b
        a = b
        b = c

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt

# --- Step 1: Create data ---
categories = np.array(['A', 'B', 'C', 'D', 'E'])      # Category labels
values = np.array([10, 24, 36, 18, 30])               # Values for each category

# --- Step 2: Vertical Bar Graph ---
plt.figure(figsize=(8,5))
plt.bar(categories, values, color='skyblue', edgecolor='black')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Vertical Bar Graph')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# --- Step 3: Horizontal Bar Graph ---
plt.figure(figsize=(8,5))
plt.barh(categories, values, color='orange', edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Categories')
plt.title('Horizontal Bar Graph')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt

# Categories and values
categories = ['A', 'B', 'C', 'D', 'E']
values = [10, 24, 36, 18, 30]

# Vertical Bar Graph
plt.bar(categories, values)       # Create vertical bars
plt.xlabel('Categories')          # X-axis label
plt.ylabel('Values')              # Y-axis label
plt.title('Vertical Bar Graph')   # Title
plt.show()                        # Display graph

# Horizontal Bar Graph
plt.barh(categories, values)      # Create horizontal bars
plt.xlabel('Values')              # X-axis label
plt.ylabel('Categories')          # Y-axis label
plt.title('Horizontal Bar Graph') # Title
plt.show()                        # Display graph

# %%
import numpy as np

# Create arrays using NumPy
categories = np.array(['A', 'B', 'C', 'D', 'E'])
values = np.array([10, 24, 36, 18, 30])

# You can do simple calculations with NumPy
values_plus_5 = values + 5          # Add 5 to each value
values_times_2 = values * 2         # Multiply each value by 2

print("Categories:", categories)
print("Original values:", values)
print("Values + 5:", values_plus_5)
print("Values x 2:", values_times_2)
# Out:
# Categories: ['A' 'B' 'C' 'D' 'E']
# Original values: [10 24 36 18 30]
# Values + 5: [15 29 41 23 35]
# Values x 2: [20 48 72 36 60]

# %%
import matplotlib.pyplot as plt

# Simple lists for plotting (can be from NumPy arrays too)
categories = ['A', 'B', 'C', 'D', 'E']
values = [10, 24, 36, 18, 30]

# Vertical Bar Graph
plt.bar(categories, values)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Vertical Bar Graph')
plt.show()

# Horizontal Bar Graph
plt.barh(categories, values)
plt.xlabel('Values')
plt.ylabel('Categories')
plt.title('Horizontal Bar Graph')
plt.show()

# %%
 numbers = [5, 2, 9, 1, 7]

print(len(numbers))      # Length of list: 5
print(min(numbers))      # Smallest: 1
print(max(numbers))      # Largest: 9
print(sum(numbers))      # Sum: 24
numbers.sort()           # Sort ascending
print(numbers)           # [1, 2, 5, 7, 9]
numbers.reverse()        # Reverse order
print(numbers)           # [9, 7, 5, 2, 1]
# Out:
# 5
# 1
# 9
# 24
# [1, 2, 5, 7, 9]
# [9, 7, 5, 2, 1]

# %%
z = [1, 2, 3, 4, 5]

print(z[0])  # First element: 1
print(z[-1]) # Last element: 5

# Change elements
z[2] = 10
print(z)

# Add elements
z.append(6)
print(z)

# Insert element at a position
z.insert(1, 99)
print(z)

# Remove elements
z.remove(10)
print(z)
# Pop element by index
popped = z.pop(2)  # Remove index 2
print(popped)      # 2
print(z)
# Out:
# 1
# 5
# [1, 2, 10, 4, 5]
# [1, 2, 10, 4, 5, 6]
# [1, 99, 2, 10, 4, 5, 6]
# [1, 99, 2, 4, 5, 6]
# 2
# [1, 99, 4, 5, 6]

# %% [markdown]
# # ***Hello My Mam...!***
#
# > Ai Maam
#
# ---
#
#
#
# ---
#
# \::
#
# 1.   List item
#
# *   List item
# *   List item
#
#
# 2.   List item

# %%
while 1:
  print(1)

# %%
t = (1, 2, 3, 4, 5)
print(t)
print(t[0])
print(t[-1])

print(t.count(2))
print(t.index(3))

print(t)

# %%
# Create a student dictionary
student = {
    'name': 'Ahso',
    'age': 21,
    'roll_no': 101,
    'subjects': ['Math', 'Physics', 'Computer Science'],
    'marks': {'Math': 95, 'Physics': 88, 'Computer Science': 92}
}

print(student)
print(student['name'])
print(student['age'])
print(student['marks']['Math'])

student['grade'] = 'A'
print(student)
student['age'] = 22
print(student)
student.pop('roll_no')
print(student)
# Out:
# {'name': 'Ahso', 'age': 21, 'roll_no': 101, 'subjects': ['Math', 'Physics', 'Computer Science'], 'marks': {'Math': 95, 'Physics': 88, 'Computer Science': 92}}
# Ahso
# 21
# 95
# {'name': 'Ahso', 'age': 21, 'roll_no': 101, 'subjects': ['Math', 'Physics', 'Computer Science'], 'marks': {'Math': 95, 'Physics': 88, 'Computer Science': 92}, 'grade': 'A'}
# {'name': 'Ahso', 'age': 22, 'roll_no': 101, 'subjects': ['Math', 'Physics', 'Computer Science'], 'marks': {'Math': 95, 'Physics': 88, 'Computer Science': 92}, 'grade': 'A'}
# {'name': 'Ahso', 'age': 22, 'subjects': ['Math', 'Physics', 'Computer Science'], 'marks': {'Math': 95, 'Physics': 88, 'Computer Science': 92}, 'grade': 'A'}

# %%
exam1_marks = {85, 90, 78, 92, 88}
exam2_marks = {80, 90, 88, 95, 75}

# Print sets
print("Exam 1 marks:", exam1_marks)
print("Exam 2 marks:", exam2_marks)

# Add a new mark
exam1_marks.add(100)
print("Exam 1 after adding 100:", exam1_marks)

# Remove a mark
exam2_marks.remove(75)
print("Exam 2 after removing 75:", exam2_marks)
all_marks = exam1_marks.union(exam2_marks)
print("All unique marks:", all_marks)


common_marks = exam1_marks.intersection(exam2_marks)
print("Marks in both exams:", common_marks)

unique_exam1 = exam1_marks.difference(exam2_marks)
print("Marks only in Exam 1:", unique_exam1)


print("Is 92 in Exam 1?", 92 in exam1_marks)
print("Is 75 in Exam 2?", 75 in exam2_marks)
# Out:
# Exam 1 marks: {85, 88, 90, 92, 78}
# Exam 2 marks: {80, 88, 90, 75, 95}
# Exam 1 after adding 100: {100, 85, 88, 90, 92, 78}
# Exam 2 after removing 75: {80, 88, 90, 95}
# All unique marks: {100, 78, 80, 85, 88, 90, 92, 95}
# Marks in both exams: {88, 90}
# Marks only in Exam 1: {100, 85, 78, 92}
# Is 92 in Exam 1? True
# Is 75 in Exam 2? False

# %%
print("AHSAN AHMAD")
print("FA24-BCS-068")
# Out:
# AHSAN AHMAD
# FA24-BCS-068
